# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader

# %%
model = nn.Sequential(
     nn.Linear(784, 128),
     nn.ReLU(),
     nn.Linear(128, 10)
)

# %%
model
# Out:
# Sequential(
#   (0): Linear(in_features=784, out_features=128, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
model.parameters()
# Out:
# <generator object Module.parameters at 0x7b13ec8927a0>

# %%
criterion = nn.CrossEntropyLoss()
criterion
# Out:
# CrossEntropyLoss()

# %%
optimizer = optim.SGD(
     model.parameters(),
     lr = 0.01,
     momentum = 0.9
)
optimizer
# Out:
# SGD (
# Parameter Group 0
#     dampening: 0
#     differentiable: False
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     momentum: 0.9
#     nesterov: False
#     weight_decay: 0
# )

# %%
images = torch.randn(100, 784)
target = torch.randint(0, 10, (100,))

dataset = TensorDataset(images, target)

train_loader = DataLoader(
     dataset,
     batch_size = 16,
     shuffle = True
)

# %%
for epoch in range(20):
     for batch, (image, target) in enumerate(train_loader):
          optimizer.zero_grad()
          output = model(image)
          loss = criterion(output, target)
          loss.backward()
          optimizer.step()
     print(f"Epoch = {epoch}     Loss = {loss.item():.4f}")
# Out:
# Epoch = 0     Loss = 2.4641
# Epoch = 1     Loss = 1.4655
# Epoch = 2     Loss = 1.3869
# Epoch = 3     Loss = 0.5697
# Epoch = 4     Loss = 0.2515
# Epoch = 5     Loss = 0.2130
# Epoch = 6     Loss = 0.0569
# Epoch = 7     Loss = 0.0628
# Epoch = 8     Loss = 0.0462
# Epoch = 9     Loss = 0.0239
# Epoch = 10     Loss = 0.0302
# Epoch = 11     Loss = 0.0242
# Epoch = 12     Loss = 0.0143
# Epoch = 13     Loss = 0.0137
# Epoch = 14     Loss = 0.0127
# Epoch = 15     Loss = 0.0156
# Epoch = 16     Loss = 0.0134
# Epoch = 17     Loss = 0.0082
# Epoch = 18     Loss = 0.0079
# Epoch = 19     Loss = 0.0083
